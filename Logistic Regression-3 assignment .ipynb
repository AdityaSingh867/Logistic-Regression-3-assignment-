# %% [markdown]
# Q1. Explain the concept of precision and recall in the context of classification models.

# %% [markdown]
# Recall: the ability of a classification model to identify all data points in a relevant class.
#
# Precision: the ability of a classification model to return only the data points in a class.

# %% [markdown]
# Q2. What is the F1 score and how is it calculated? How is it different from precision and recall?

# %% [markdown]
# F1 score is a machine learning evaluation metric that measures a model's accuracy.
#
# How is it different from precision and recall = F1-Score is a measure combining both precision and recall.

# %% [markdown]
# Q3. What is ROC and AUC, and how are they used to evaluate the performance of classification models?

# %% [markdown]
# ROC (Receiver Operating Characteristic) is a graphical plot that illustrates the performance of a binary classification model at various classification thresholds.
#
# AUC (Area Under the ROC Curve) is a metric that quantifies the overall performance of a binary classification model based on the ROC curve
#
# ROC curves and AUC are commonly used to evaluate the performance of classification models, especially in binary classification problems

# %% [markdown]
# Q4. How do you choose the best metric to evaluate the performance of a classification model?
#
# What is multiclass classification and how is it different from binary classification?

# %% [markdown]
# Metrics like accuracy, precision, recall are good ways to evaluate classification models for balanced datasets, but if the data is imbalanced then other methods like ROC/AUC perform better in evaluating the model performance.

# %% [markdown]
# In  binary classification there is only two output like student Pass/fail in test so , there is only two output Pass or Fail
#
# But in multiclass classification there is a more than two output like we consider output is [1,2,3,4] so , there is more than two output 1,2,3,4

# %% [markdown]
# Q5. Explain how logistic regression can be used for multiclass classification.

# %% [markdown]
# Logistic regression is a binary funcation we use Multinomial Logistic Regression for multiclass classification but the question how they do that:
#
# let's consider there is three(3) type of output like in photo

# %% [markdown]
# ![WhatsApp Image 2023-05-16 at 13.50.18 (2).jpeg](attachment:dd9c447c-7209-4b7f-a6ae-0c547b220141.jpeg)

# %% [markdown]
# than Logistic regression creat a best fit line , Logistic regression creat best fit line like that there is one hand side of best fit line only one output data and othere side there is to data like in photo

# %% [markdown]
# ![WhatsApp Image 2023-05-16 at 13.50.18 (1).jpeg](attachment:a4b61afe-7358-4aae-9daf-253838eec79d.jpeg)

# %% [markdown]
# so , the tow data Logistic regression consider these both data as 1 and another data is already 1 so , Logistic regression make multiple data as binary classification

# %% [markdown]
# ![WhatsApp Image 2023-05-16 at 13.50.18.jpeg](attachment:4be3887b-0497-47c2-bc15-c37d96e3c11f.jpeg)

# %% [markdown]
# Q6. Describe the steps involved in an end-to-end project for multiclass classification.

# %% [markdown]
# These are steps of end-to-end Diabetes Prediction project :
#
# - First a fall we take dataset
# - and import it in flask library using pd.read_csv because Diabetes Prediction data is present as csv
# - check null values if null values is given than fill it by using mean , median , mode it is depend upon the dataset columns
# - and check statistic analysis by using describe ,  and check min_value , max_value , std , etc .
# - did EDA if needed if not than you skip this
# - did feature Engineering because feature Engineering is much important of before making any model by using any type of dataset
# - convert object_type in int_type or float_type because model always take int or float more traning and test
# - did feature selection because feature selection is very important for increasing the model accuracy
# - did train_test_split
# - make X_train , X_test , y_train , y_test
# - after these all steps did StandardScaler
# - make pickle file of StandardScaler for web application
# - and did Logistic regression
# - and did gride search cv
# - before doing gride search cv make parameters variable and insert parameters that you want to insert in gride search cv
# - than you did gride search cv and give parameters and cv , etc
# - save it for model prediction that use when we make web application
# - after thses all stpes we finall make web application
# - make some folder in workshope of flask library like Notebooks , model , templates , dataset
# - in templates folder we import index.html , home.html , for making we application they help for design , in model folder you insert pickle both pickle that we make before
# - for making we application open app.py in flask
# - than import some library like pandas , numpy , pickle , from flask import flask , request , app , render_templates
# - than write code for web application
# - these are code that i written :
#
# from flask import Flask , render_template , request , app , Response
#
# import pandas as pd
#
# import seaborn as sns
#
# import pickle
#
# app = Flask(__name__)
#
# scaler = pickle.load(open('/config/workspace/model/scaler.pkl' , 'rb'))
#
# model = pickle.load(open('/config/workspace/model/modelforpred.pkl' , 'rb'))
#
# @app.route('/')
#
# def index():
#
#     return render_template('index.html')
#
#
# @app.route('/predict' , methods = ['GET' , 'POST'])
#
# def predict_datapoint():
#
#     result = ''
#
#     if request.method=='POST':
#
#         Pregnancies = float(request.form.get('Pregnancies'))
#
#         Glucose = float(request.form.get('Glucose'))
#
#         BloodPressure = float(request.form.get('BloodPressure'))
#
#         SkinThickness = float(request.form.get('SkinThickness'))
#
#         Insulin = float(request.form.get('Insulin'))
#
#         BMI = float(request.form.get('BMI'))
#
#         DiabetesPedigreeFunction = float(request.form.get('DiabetesPedigreeFunction'))
#
#         Age = float(request.form.get('Age'))
#
#         new_data = scaler.transform([[Pregnancies ,Glucose ,BloodPressure ,SkinThickness ,Insulin ,BMI ,DiabetesPedigreeFunction ,Age]])
#
#         predict = model.predict(new_data)
#
#         if predict[0]==1:
#
#             result = 'Diabatic'
#
#         else:
#
#             result = 'Non-Diabatic'
#
#         return render_template('single_prediction.html' , result=result)
#
#     else:
#
#         return render_template('home.html')
#
#
#
# if __name__=="__main__":
#
#     app.run(host="0.0.0.0")
#
#
# - after this we save this on github and deploy on aws.

# %% [markdown]
# Q7. What is model deployment and why is it important?

# %% [markdown]
# Model deployment refers to the process of making a trained machine learning model available for use in a production environment, where it can receive input data, make predictions, and provide output results. It is important because it allows organizations to operationalize and leverage the predictive capabilities of their models, enabling real-time decision-making, automation, and integration into existing systems, leading to tangible business value

# %% [markdown]
# Q8. Explain how multi-cloud platforms are used for model deployment.

# %% [markdown]
# Multi-cloud platforms facilitate the deployment of machine learning models across multiple cloud service providers. They offer a unified framework for seamless management, scaling, and monitoring of models. Leveraging the strengths of different cloud providers, organizations can achieve flexibility, reliability, and cost optimization, while avoiding vendor lock-in. Multi-cloud platforms streamline model deployment in a distributed cloud environment.

# %% [markdown]
# Q9. Discuss the benefits and challenges of deploying machine learning models in a multi-cloud
# environment.

# %% [markdown]
# Benefits of deploying machine learning models in a multi-cloud environment include increased flexibility, leveraging specialized services from different providers, and avoiding vendor lock-in. Challenges include complex infrastructure management, data synchronization, security and privacy concerns, increased complexity in deployment and integration, and potential differences in APIs and tooling across cloud platforms, requiring additional efforts for compatibility and maintenance.
